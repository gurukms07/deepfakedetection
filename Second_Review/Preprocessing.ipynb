# %%
#Mount our google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#download and unzip the data from google drive Colab environment
from google_drive_downloader import GoogleDriveDownloader as gdd
#use only file id of the link
url = '1P9Sxln0HeMlipAHdsDGTkWSI-haDW1LS'
gdd.download_file_from_google_drive(file_id = url,dest_path='./DeepfakeData.zip',unzip=True)

# %%
#To get the average frame count 
import glob
import numpy as np
import cv2

# %%
video_files =  glob.glob('/content/drive/MyDrive/DeepfakeData/*.mp4')
#video_files1 =  glob.glob('/content/dfdc_train_part_0/*.mp4')
#video_files += video_files1
frame_count = []
for video_file in video_files:
  cap = cv2.VideoCapture(video_file)
  if(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))<150):
    video_files.remove(video_file)
    continue
  frame_count.append(int(cap.get(cv2.CAP_PROP_FRAME_COUNT)))
print("frames" , frame_count)
print("Total number of videos: " , len(frame_count))
print('Average frame per video:',np.mean(frame_count))
# Out:
# frames [464, 239, 469, 459, 479, 529, 326, 534, 350, 520, 303, 380, 320, 364, 379, 371, 322, 350, 327, 330, 357, 316, 441, 398, 172, 318, 517, 535, 351, 373, 397, 376, 313, 410, 303, 435, 333, 314, 459, 224, 308, 489, 363, 339, 340, 327, 349, 452, 317, 510, 309, 332, 400, 345, 390, 316, 459, 352, 466, 337, 400, 276, 341, 305, 312, 324, 335, 201, 315, 284, 371, 325, 320, 328, 298, 308, 269, 327, 451, 338, 323, 334, 274, 315, 306, 311, 272, 247, 322, 337, 409, 199, 365, 262, 347, 328, 311, 310, 334, 319, 328, 519, 324, 317, 225, 322, 338, 334, 412, 306, 315, 422, 333, 273, 178, 505, 337, 312, 283, 359, 325, 234, 165, 332, 309, 308, 327, 333, 250, 321, 308, 317, 309, 323, 316, 314, 325, 310, 292, 321, 337, 323, 307, 243, 315, 339, 315, 319, 355, 318, 319, 308, 342, 341, 306, 315, 186, 340, 318, 322, 288, 338, 336, 283, 331, 350, 311, 331, 249, 320, 317, 330, 334, 307, 295, 327, 380, 376, 361, 322, 470, 445, 307, 425, 516, 383, 372, 398, 499, 361, 497, 458, 458, 428, 380, 409, 459, 477, 
# ...

# %%
# to extract frame
def frame_extract(path):
  vidObj = cv2.VideoCapture(path) 
  success = 1
  while success:
      success, image = vidObj.read()
      if success:
          yield image

# %%
# !pip3 install face_recognition
# !mkdir '/content/drive/My Drive/Preprocessed Video'
# Out:
# ...
#      |████████████████████████████████| 100.1 MB 26 kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566186 sha256=af0402550ec092767dd4f7c179ad563ba2bbf3b7be5faafd127fdfe029eb48e5
#   Stored in directory: /root/.cache/pip/wheels/d6/81/3c/884bcd5e1c120ff548d57c2ecc9ebf3281c9a6f7c0e7e7947a
# Successfully built face-recognition-models
# ...
# mkdir: cannot create directory ‘/content/drive/My Drive/Preprocessed Video’: File exists

# %%
import os
import face_recognition
from tqdm.autonotebook import tqdm

# %%
# process the frames
def create_face_videos(path_list,out_dir):
  already_present_count =  glob.glob(out_dir+'*.mp4')
  print("No of videos already present " , len(already_present_count))
  for path in tqdm(path_list):
    out_path = os.path.join(out_dir,path.split('/')[-1])
    file_exists = glob.glob(out_path)
    if(len(file_exists) != 0):
      print("File Already exists: " , out_path)
      continue
    frames = []
    flag = 0
    face_all = []
    frames1 = []
    out = cv2.VideoWriter(out_path,cv2.VideoWriter_fourcc('M','J','P','G'), 30, (112,112))
    for idx,frame in enumerate(frame_extract(path)):
      if(idx <= 150):
        frames.append(frame)
        if(len(frames) == 4):
          faces = face_recognition.batch_face_locations(frames)
          for i,face in enumerate(faces):
            if(len(face) != 0):
              top,right,bottom,left = face[0]
            try:
              out.write(cv2.resize(frames[i][top:bottom,left:right,:],(112,112)))
            except:
              pass
          frames = []
    try:
      del top,right,bottom,left
    except:
      pass
    out.release()

# %%
create_face_videos(video_files,'/content/drive/My Drive/Preprocessed Video/')
# Out:
# No of videos already present  294
#   0%|          | 0/518 [00:00<?, ?it/s]
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_id2_0005.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id1_id6_0007.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_id2_0004.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0008.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0000.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0005.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0007.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0003.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0004.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0006.mp4
# File Already exists:  /content/drive/My Drive/Preprocessed Video/id0_0002.mp4
# ...
